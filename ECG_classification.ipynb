# %% [markdown]
# ## Общей задачей является обучение модели детектировать наличие QRS комплекса в сигнале ЭКГ.
# __В процессе решения будет создан бинарный классификатор, который по небольшой области размером в 200 временных отчетов (вырезанной части исходного сигнала) научится определять, имеется ли по центру участка QRS пик.
# В качестве ML модели будет использоваться градиентный бустинг.__<br>
# >То есть на вход классификатора будет подаваться маленькая область сигнала, а на выходе мы говорить, находиться ли по центру этой области его QRS комплекс или нет. Тем самым создадим бинарную классификацию 1 - есть, 0 - нет.
#
# Обучение будет происходить по данным ЭКГ сигналов большого числа пациентов. Датасет сигналов электрокардиограммы для обучения и тестирования будет взят с MIT-BIH Database.<br>
#
# _Для итогового определения QRS комплеса на неизвестном сигнале будет использоваться подход со скольжением небольшого окна по сигналу и последующей классификацией каждой области на наличие пика с помощью заранее обученной модели._
#
# Цель данного раздела проекта - обучить классификатор находить все QRS комплексы. Это позволит нам для любого сигнала точно опредлять период кардиоцикла и моменты возникновения пика QRS. Благодаря этому мы сможем детектировать с высокой точностью полные периоды цикла ЭКГ и для кажого периода рисовать Векторное представление движения диполя.

# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
import os
from scipy.signal import find_peaks
from sklearn.model_selection import train_test_split
from catboost import CatBoost
from matplotlib.pyplot import figure
from sklearn import datasets
from catboost.utils import eval_metric
import random
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %% [markdown]
# Прочтем из архива, который скачали по ссылке https://www.kaggle.com/datasets/mondejar/mitbih-database?resource=download&select=100.csv все файлы и выберем те, что являются csv

# %%
list_files = os.listdir('ECG_peak_detect_dataset')
list_csv = []
for name in list_files:
    if '.csv' in name:
        list_csv.append(name)
print(', '.join(list_csv))
# Out:
# 100.csv, 101.csv, 102.csv, 103.csv, 104.csv, 105.csv, 106.csv, 107.csv, 108.csv, 109.csv, 111.csv, 112.csv, 113.csv, 114.csv, 115.csv, 116.csv, 117.csv, 118.csv, 119.csv, 121.csv, 122.csv, 123.csv, 124.csv, 200.csv, 201.csv, 202.csv, 203.csv, 205.csv, 207.csv, 208.csv, 209.csv, 210.csv, 212.csv, 213.csv, 214.csv, 215.csv, 217.csv, 219.csv, 220.csv, 221.csv, 222.csv, 223.csv, 228.csv, 230.csv, 231.csv, 232.csv, 233.csv, 234.csv

# %%
len(list_csv)
# Out:
# 48

# %% [markdown]
# Таким образом, у нас есть 48 разных пациентов и их результаты записи ЭКГ. Возьмем на train все области сигнала с QRS по центру данной области для 46 первых пациентов, а тестироваться будем на участках сигнала последних двух пациентов (233.csv и 234.csv)

# %%
path = 'ECG_peak_detect_dataset/'
list_train = list_csv[:-2]
list_test = list_csv[46:]
len(list_train)
# Out:
# 46

# %%
list_test
# Out:
# ['233.csv', '234.csv']

# %% [markdown]
# Приступим подготавливать тренировочную выборку: <br/>
# Для поиска QRS будем использовать find_peaks модуль.
# <br/>Рассмотрим на примере 100.csv как происходит подготовка данных для обучения и теста а потом реализуем всю подготовку в одном большом цикле.

# %%
data = pd.read_csv('D:\Python_notebooks\project_files\ECG/100.csv')
columns = data.columns

# %%
signal = data[columns[1]]
print(len(signal))
signal = signal[0:25000]
figure(figsize=(9, 4), dpi=80);
plt.plot(signal[100:1200]);
# Out:
# 650000

# %%
peaks = find_peaks(signal, distance=200)
print('Координаты пиков:',peaks[0])
figure(figsize=(9, 4), dpi=80);
plt.plot(signal)
plt.scatter(peaks[0], signal[peaks[0]], color='red')
plt.xlim([0, 17000]);
# Out:
# Координаты пиков: [   77   370   663   947  1231  1515  1809  2045  2403  2706  2998  3283
#   3560  3863  4171  4466  4765  5061  5347  5634  5918  6215  6527  6824
#   7106  7393  7670  7953  8246  8539  8837  9142  9432  9710  9998 10283
#  10591 10895 11191 11480 11781 12066 12351 12645 12950 13267 13562 13842
#  14131 14423 14711 15012 15310 15607 15900 16183 16465 16755 17058 17359
#  17657 17947 18227 18514 18796 19081 19389 19694 19989 20272 20554 20838
#  21131 21424 21729 22030 22321 22603 22881 23164 23454 23757 24053 24346
#  24626 24914]

# %%
window = 200  # Размер окна наблюдения
dataset = []
for i in range(0, len(signal)-window, 12):
    piece = signal[i:i+window] / np.max(np.abs(signal[i:i+window])) 
    piece = piece - np.mean(piece)  # нормолизация как деление на максимум а далее отнимание среднего
    is_peak = 0
    middle = (i + i + window) / 2
    for peak in peaks[0]:
        if peak >= middle - 10 and peak < middle + 10:
            is_peak = 1
            break
    piece = np.append(piece, is_peak)
    dataset.append(piece)

# %%
df = pd.DataFrame(dataset)
df.tail()
# Out:
#            0         1         2         3         4         5         6
# 2062 -0.007784 -0.006182 -0.005381 -0.003778 -0.005381 -0.007784 -0.006182  \
# 2063 -0.002969 -0.004571 -0.002969 -0.003770 -0.001366 -0.005373 -0.005373
# 2064 -0.004483 -0.002881 -0.002079 -0.004483 -0.003682 -0.006887 -0.005284
# 2065 -0.006114 -0.008518 -0.007716 -0.005312 -0.006114 -0.007716 -0.006114
# 2066 -0.008710 -0.006306 -0.005505 -0.006306 -0.007909 -0.008710 -0.008710
#
#            7         8         9    ...       191       192       193
# 2062 -0.005381 -0.004579 -0.002175  ... -0.020605 -0.019804 -0.019804  \
# 2063 -0.003770 -0.001366 -0.001366  ... -0.020597 -0.018994 -0.018193
# 2064 -0.006887 -0.006086 -0.004483  ... -0.020509 -0.019708 -0.018105
# 2065 -0.006114 -0.006114 -0.006114  ... -0.019736 -0.018934 -0.017332
# 2066 -0.007909 -0.006306 -0.006306  ... -0.015921 -0.017524 -0.016723
#
#            194       195       196       197       198       199  200
# 2062 -0.019002 -0.019804 -0.020605 -0.023009 -0.022208 -0.021406  0.0
# 2063 -0.014988 -0.018193 -0.016591 -0.019796 -0.018994 -0.018994  0.0
# 2064 -0.014900 -0.014900 -0.016502 -0.017304 -0.019708 -0.018105  0.0
# 2065 -0.014928 -0.017332 -0.016530 -0.018133 -0.017332 -0.016530  0.0
# 2066 -0.015921 -0.015921 -0.016723 -0.018325 -0.017524 -0.015921  0.0
#
# [5 rows x 201 columns]

# %% [markdown]
# Для одного лишь пациента получается такой большой датафрейм с данными, состоящий из двухсот значений сигнала и результата в столбце под номером 200, где указано 1 если это область содержит QRS по центру и 0 есть нет

# %%
df[200].value_counts() # выдаст сколько элементов содержат пики а сколько нет
# Out:
# 200
# 0.0    1923
# 1.0     144
# Name: count, dtype: int64

# %% [markdown]
# У нас слишком непропорциональное число 1 и 0 классов, так что сделаем чтобы соотношение 0 и 1 стало примерно 50 на 50
# Для этого рандомно удалим часть строк из датафрема где стоят 0 как разультат классификации

# %%
df['ind'] = range(df.shape[0])
index_class0 = df[df[200]==0]['ind']
index_class1 = df[df[200]==1]['ind']
index_class0_downsampled = np.random.choice(index_class0, size=df[df[200]==1].shape[0], replace=False)

# %%
index_class0.shape
# Out:
# (1923,)

# %%
index_class0_downsampled.shape
# Out:
# (144,)

# %%
index_class1.shape[0]
# Out:
# 144

# %%
connected_01 =list(index_class0_downsampled) + list(index_class1)
print(len(connected_01))
df_new = df.query("ind in @connected_01")
df_new = df_new.drop('ind', axis=1)
df_new = df_new.reset_index()
df_new = df_new.drop('index', axis=1)
# Out:
# 288

# %%
df_new.head()
# Out:
#         0         1         2         3         4         5         6
# 0 -0.022306 -0.011058 -0.002878 -0.001856 -0.003901 -0.005946 -0.002878  \
# 1 -0.000924  0.000726  0.002376 -0.000924 -0.003399 -0.004224 -0.001749
# 2 -0.001955 -0.000305  0.000520  0.001345  0.001345  0.000520  0.002170
# 3  0.002186  0.004662  0.006312  0.003837  0.002186  0.000536  0.002186
# 4 -0.003261 -0.004296 -0.002226 -0.002226 -0.002226 -0.005331 -0.003261
#
#         7         8         9    ...       191       192       193       194
# 0 -0.001856  0.000189  0.001212  ... -0.002878 -0.001856  0.000189  0.001212  \
# 1  0.000726 -0.000099 -0.000924  ... -0.021551 -0.020726 -0.020726 -0.019076
# 2  0.001345  0.003820  0.002170  ... -0.025883 -0.024233 -0.023408 -0.022583
# 3  0.003837  0.004662  0.006312  ... -0.020091 -0.015140 -0.012665 -0.008540
# 4 -0.003261 -0.003261 -0.001190  ...  0.002950  0.003986  0.006056  0.008126
#
#         195       196       197       198       199  200
# 0  0.002234  0.002234  0.001212  0.003257  0.002234  0.0
# 1 -0.020726 -0.024026 -0.024851 -0.024026 -0.021551  1.0
# 2 -0.023408 -0.025883 -0.026708 -0.024233 -0.022583  1.0
# 3 -0.007715 -0.006889 -0.007715 -0.003589 -0.001114  0.0
# 4  0.006056  0.006056  0.006056  0.008126  0.007091  0.0
#
# [5 rows x 201 columns]

# %% [markdown]
# Теперь классы сбалансированы для одного пациента

# %%
df_new[200].value_counts()
# Out:
# 200
# 0.0    144
# 1.0    144
# Name: count, dtype: int64

# %% [markdown]
# Посмотрим как выглядят данные маленькие части сигналов которые мы классифицировали как 1 или 0:

# %% [markdown]
# #### Примеры фрагментов с классом 0 (QRS отсутвует в центральной области диапазона)

# %%
fig, axes = plt.subplots(3, 3, figsize=(15,8))
for i, ax in enumerate(axes.flatten()):
    ax.plot(df_new[df_new[200]==0].iloc[i , :200])
plt.show()

# %% [markdown]
# #### Примеры фрагментов с классом 1 (QRS присутствует в центральной области диапазона)

# %%
fig, axes = plt.subplots(3, 3, figsize=(15,8))
for i, ax in enumerate(axes.flatten()):
    ax.plot(df_new[df_new[200]==1].iloc[random.randint(0, index_class1.shape[0]-1) , :200])
plt.show()

# %% [markdown]
#  __Все что было написано выше было лишь демонстрацией и пояснением к работе моего кода. Но прошлый фрагмент был адресован лишь к одному пациенту. Так что теперь в цикле проделаем эти же преобразования и для других пациентов и конкатиноруем их результаты такого цикла в общий трейновый датасет. А так же создадим отдельно тестовый датасет по такому же правилу.__

# %%
def preparation (list_csv, path, dist):
    df_merged = pd.DataFrame()
    for name in list_csv:
        data = pd.read_csv(path+name)
        columns = data.columns
        signal = data[columns[1]]
        signal = signal[0:25000]
        peaks = find_peaks(signal, distance=dist[name])
        window = 200  # Размер окна наблюдения
        dataset = []
        for i in range(0, len(signal)-window, 2):
            piece = signal[i:i+window] / np.max(np.abs(signal[i:i+window])) 
            piece = piece - np.mean(piece)  # нормолизация как деление на максимум а далее отнимание среднего
            is_peak = 0
            middle = (i + i + window) / 2
            for peak in peaks[0]:
                if peak >= middle - 3 and peak < middle + 3:
                    is_peak = 1
                    break
            piece = np.append(piece, is_peak)
            dataset.append(piece)        
        df = pd.DataFrame(dataset)
        df['ind'] = range(df.shape[0])
        index_class0 = df[df[200]==0]['ind']
        index_class1 = df[df[200]==1]['ind']
        index_class0_downsampled = np.random.choice(index_class0, size=df[df[200]==1].shape[0], replace=False)
        connected_01 =list(index_class0_downsampled) + list(index_class1)
        df_new = df.query("ind in @connected_01")
        df_new = df_new.drop('ind', axis=1)
        df_new = df_new.reset_index()
        df_new = df_new.drop('index', axis=1)        
        df_merged = pd.concat([ df_merged, df_new])
    return df_merged

# %% [markdown]
# Значение дистанции на самом деле различно для каждого из сигналов, ведь частота сердцебиения у каждого человека может быть различной. Убедимся, что для всех dist = 200 не лучший вариант.

# %%
for name in list_train[-20:-15]:
        data = pd.read_csv(path+name)
        columns = data.columns
        signal = data[columns[1]]
        signal = signal[0:25000]
        peaks = find_peaks(signal, distance=200)
        figure(figsize=(15, 2), dpi=80);
        plt.plot(signal)
        plt.title(name)
        plt.scatter(peaks[0], signal[peaks[0]], color='red')
        plt.xlim([0, 15000]);

# %% [markdown]
# Я руками провел исследование и нашел для каждого csv свой подходящий параметр dist. Так что задам его в виде словарика где ключами будет выступать имена сsv

# %%
numbers = list(200*np.ones(len(list_train)))
dist = dict(zip(list_train, numbers))
dist['114.csv'] = 230
dist['117.csv'] = 230
dist['119.csv'] = 300
dist['123.csv'] = 300
dist['124.csv'] = 300
dist['202.csv'] = 300
dist['207.csv'] = 500
dist['208.csv'] = 150
dist['215.csv'] = 150
dist
# Out:
# {'100.csv': 200.0,
#  '101.csv': 200.0,
#  '102.csv': 200.0,
#  '103.csv': 200.0,
#  '104.csv': 200.0,
#  '105.csv': 200.0,
#  '106.csv': 200.0,
#  '107.csv': 200.0,
#  '108.csv': 200.0,
#  '109.csv': 200.0,
#  '111.csv': 200.0,
#  '112.csv': 200.0,
#  '113.csv': 200.0,
#  '114.csv': 230,
#  '115.csv': 200.0,
#  '116.csv': 200.0,
#  '117.csv': 230,
#  '118.csv': 200.0,
#  '119.csv': 300,
#  '121.csv': 200.0,
#  '122.csv': 200.0,
#  '123.csv': 300,
#  '124.csv': 300,
#  '200.csv': 200.0,
#  '201.csv': 200.0,
#  '202.csv': 300,
#  '203.csv': 200.0,
#  '205.csv': 200.0,
#  '207.csv': 500,
#  '208.csv': 150,
#  '209.csv': 200.0,
#  '210.csv': 200.0,
#  '212.csv': 200.0,
#  '213.csv': 200.0,
#  '214.csv': 200.0,
#  '215.csv': 150,
#  '217.csv': 200.0,
#  '219.csv': 200.0,
#  '220.csv': 200.0,
#  '221.csv': 200.0,
#  '222.csv': 200.0,
#  '223.csv': 200.0,
#  '228.csv': 200.0,
#  '230.csv': 200.0,
#  '231.csv': 200.0,
#  '232.csv': 200.0}

# %%
df_train = preparation(list_train, path, dist)

# %%
list_test
# Out:
# ['233.csv', '234.csv']

# %% [markdown]
# Значение дистанции на самом деле различно для каждого из сигналов, ведь частота сердцебиения у каждого человека может быть различной. Экспериментально убедимся, что при условии dist=150 для test очень даже неплохие результаты

# %%
for name in list_test:
        data = pd.read_csv(path+name)
        columns = data.columns
        signal = data[columns[1]]
        signal = signal[0:25000]
        peaks = find_peaks(signal, distance=150)
        figure(figsize=(15, 2), dpi=80)
        plt.plot(signal)
        plt.title(name)
        plt.scatter(peaks[0], signal[peaks[0]], color='red')
        plt.xlim([0, 15000])
        plt.show()

# %%
numbers = list(150*np.ones(len(list_test)))
dist = dict(zip(list_test, numbers))

# %%
df_test = preparation(list_test, path, dist)

# %%
df_train.head()
# Out:
#         0         1         2         3         4         5         6
# 0  0.003519  0.002694  0.004344  0.002694  0.003519  0.003519  0.001044  \
# 1  0.003915  0.000615  0.000615 -0.000210  0.001440  0.001440  0.003090
# 2  0.000223  0.001873  0.001873  0.001048  0.000223 -0.002252  0.001048
# 3 -0.002896 -0.003721 -0.001246  0.001229  0.000404 -0.000421 -0.002071
# 4 -0.001031  0.001444  0.000619 -0.000206 -0.001856 -0.003507 -0.002682
#
#         7         8         9    ...       191       192       193       194
# 0  0.001869  0.001869  0.001044  ... -0.017108 -0.019583 -0.019583 -0.022059  \
# 1  0.002265 -0.000210 -0.001035  ... -0.019187 -0.018362 -0.017537 -0.020012
# 2  0.000223 -0.000602 -0.001427  ... -0.019579 -0.019579 -0.017104 -0.016279
# 3 -0.003721 -0.002896 -0.001246  ... -0.020223 -0.023523 -0.024348 -0.023523
# 4 -0.001031 -0.000206  0.000619  ... -0.024134 -0.023309 -0.020833 -0.022483
#
#         195       196       197       198       199  200
# 0 -0.022884 -0.022884 -0.019583 -0.019583 -0.020408  0.0
# 1 -0.020837 -0.017537 -0.017537 -0.016712 -0.016712  0.0
# 2 -0.017929 -0.019579 -0.020404 -0.020404 -0.018754  0.0
# 3 -0.021048 -0.022698 -0.023523 -0.024348 -0.026823  1.0
# 4 -0.023309 -0.024134 -0.026609 -0.024959 -0.024134  1.0
#
# [5 rows x 201 columns]

# %%
df_train[0].value_counts()
# Out:
# 0
# -0.020000    3
#  0.022500    2
# -0.006204    2
# -0.026374    2
#  0.000000    2
#             ..
# -0.050757    1
#  0.085342    1
#  0.078098    1
# -0.035077    1
#  0.003894    1
# Name: count, Length: 23429, dtype: int64

# %%
df_test[200].value_counts()
# Out:
# 200
# 1.0    678
# 0.0    678
# Name: count, dtype: int64

# %% [markdown]
# Теперь данные на train и test готовы, так что посмотрим, что из себя представляют пики QRS по центру для различных рандомно выбранных данных из train датафрейма (__то есть класс 1__)

# %%
fig, axes = plt.subplots(6, 3, figsize=(15,15))
for i, ax in enumerate(axes.flatten()):
    ax.plot(df_train[df_train[200]==1].iloc[random.randint(0, df_train[df_train[200]==1].shape[0]-1) , :200])
plt.show()

# %% [markdown]
# Посмотрим, что из себя представляют фрагменты сигнала, в которых по центру отсутвует QRS комплекс (__то есть класс 0__)

# %%
fig, axes = plt.subplots(6, 3, figsize=(15,15))
for i, ax in enumerate(axes.flatten()):
    ax.plot(df_train[df_train[200]==0].iloc[random.randint(0, df_train[df_train[200]==0].shape[0]-1) , :200])
plt.show()

# %% [markdown]
# ### Обучение градиентного бустинга (CatBoost)

# %%
X_train = df_train.iloc[: , :200]
Y_train = df_train[200]
X_test = df_test.iloc[: , :200]
Y_test = df_test[200]

# %%
X_train.shape
# Out:
# (23466, 200)

# %%
Y_train.shape
# Out:
# (23466,)

# %%
X_test.shape
# Out:
# (1356, 200)

# %%
Y_test.shape
# Out:
# (1356,)

# %%
booster = CatBoost(params={'iterations':100, 'loss_function':'Logloss'})

booster.fit(X_train, Y_train, eval_set=(X_test, Y_test))
booster.set_feature_names([str(i) for i in range(200)])

test_preds = booster.predict(X_test, prediction_type="Class")
train_preds = booster.predict(X_train, prediction_type="Class")
# Out:
# Learning rate set to 0.188108
# 0:	learn: 0.4566418	test: 0.4456110	best: 0.4456110 (0)	total: 80.7ms	remaining: 7.99s
# 1:	learn: 0.3319760	test: 0.3164020	best: 0.3164020 (1)	total: 109ms	remaining: 5.33s
# 2:	learn: 0.2533642	test: 0.2404183	best: 0.2404183 (2)	total: 135ms	remaining: 4.38s
# 3:	learn: 0.2123533	test: 0.2007406	best: 0.2007406 (3)	total: 164ms	remaining: 3.93s
# 4:	learn: 0.1863286	test: 0.1715238	best: 0.1715238 (4)	total: 191ms	remaining: 3.63s
# 5:	learn: 0.1644025	test: 0.1447069	best: 0.1447069 (5)	total: 220ms	remaining: 3.44s
# 6:	learn: 0.1544924	test: 0.1346628	best: 0.1346628 (6)	total: 256ms	remaining: 3.4s
# 7:	learn: 0.1436173	test: 0.1244896	best: 0.1244896 (7)	total: 288ms	remaining: 3.31s
# 8:	learn: 0.1365524	test: 0.1185449	best: 0.1185449 (8)	total: 316ms	remaining: 3.19s
# 9:	learn: 0.1318661	test: 0.1155576	best: 0.1155576 (9)	total: 343ms	remaining: 3.08s
# 10:	learn: 0.1265818	test: 0.1075050	best: 0.1075050 (10)	total: 369ms	remaining: 2.98s
# 11:	learn: 0.1220034	test: 0.1038029	best: 0.1038029 (11)	total: 396ms	remaining: 2.91s
# 12:	learn: 0.1199511	test: 0.1026812	best: 0.1026812 (12)	total: 428ms	remaining: 2.86s
# 13:	learn: 0.1176425	test: 0.1033911	best: 0.1026812 (12)	total: 465ms	remaining: 2.86s
# 14:	learn: 0.1151763	test: 0.1027408	best: 0.1026812 (12)	total: 502ms	remaining: 2.85s
# 15:	learn: 0.1139047	test: 0.1016385	best: 0.1016385 (15)	total: 537ms	remaining: 2.82s
# 16:	learn: 0.1119506	test: 0.0995972	best: 0.0995972 (16)	total: 565ms	remaining: 2.76s
# 17:	learn: 0.1100065	test: 0.0981607	best: 0.0981607 (17)	total: 594ms	remaining: 2.71s
# 18:	learn: 0.1080311	test: 0.0962065	best: 0.0962065 (18)	total: 621ms	remaining: 2.65s
# 19:	learn: 0.1063375	test: 0.0964363	best: 0.0962065 (18)	total: 650ms	remaining: 2.6s
# 20:	learn: 0.1053676	test: 0.0953534	best: 0.0953534 (20)	total: 681ms	remaining: 2.56s
# 21:	learn: 0.1040701	test: 0.0949825	best: 0.0949825 (21)	total: 709ms	remaining: 2.51s
# 22:	learn: 0.1025871	test: 0.0946166	best: 0.0946166 (22)	total: 737ms	remaining: 2.47s
# 23:	learn: 0.1012974	test: 0.0915527	best: 0.0915527 (23)	total: 762ms	remaining: 2.41s
# 24:	learn: 0.0995215	test: 0.0913007	best: 0.0913007 (24)	total: 788ms	remaining: 2.36s
# 25:	learn: 0.0974584	test: 0.0919028	best: 0.0913007 (24)	total: 823ms	remaining: 2.34s
# 26:	learn: 0.0967717	test: 0.0917636	best: 0.0913007 (24)	total: 852ms	remaining: 2.3s
# 27:	learn: 0.0959353	test: 0.0910826	best: 0.0910826 (27)	total: 878ms	remaining: 2.26s
# 28:	learn: 0.0952379	test: 0.0907314	best: 0.0907314 (28)	total: 907ms	remaining: 2.22s
# 29:	learn: 0.0936761	test: 0.0901152	best: 0.0901152 (29)	total: 936ms	remaining: 2.18s
# 30:	learn: 0.0930943	test: 0.0897029	best: 0.0897029 (30)	total: 961ms	remaining: 2.14s
# 31:	learn: 0.0925008	test: 0.0891075	best: 0.0891075 (31)	total: 989ms	remaining: 2.1s
# 32:	learn: 0.0913714	test: 0.0884010	best: 0.0884010 (32)	total: 1.01s	remaining: 2.06s
# 33:	learn: 0.0905137	test: 0.0881576	best: 0.0881576 (33)	total: 1.04s	remaining: 2.02s
# 34:	learn: 0.0897712	test: 0.0889399	best: 0.0881576 (33)	total: 1.07s	remaining: 1.99s
# 35:	learn: 0.0890605	test: 0.0895044	best: 0.0881576 (33)	total: 1.1s	remaining: 1.96s
# 36:	learn: 0.0885667	test: 0.0888503	best: 0.0881576 (33)	total: 1.13s	remaining: 1.93s
# 37:	learn: 0.0881451	test: 0.0894063	best: 0.0881576 (33)	total: 1.16s	remaining: 1.89s
# 38:	learn: 0.0874991	test: 0.0893906	best: 0.0881576 (33)	total: 1.19s	remaining: 1.86s
# 39:	learn: 0.0869048	test: 0.0901567	best: 0.0881576 (33)	total: 1.22s	remaining: 1.83s
# 40:	learn: 0.0860119	test: 0.0897132	best: 0.0881576 (33)	total: 1.25s	remaining: 1.8s
# 41:	learn: 0.0849199	test: 0.0889497	best: 0.0881576 (33)	total: 1.27s	remaining: 1.76s
# 42:	learn: 0.0843461	test: 0.0887810	best: 0.0881576 (33)	total: 1.3s	remaining: 1.73s
# 43:	learn: 0.0831232	test: 0.0878304	best: 0.0878304 (43)	total: 1.34s	remaining: 1.7s
# 44:	learn: 0.0825261	test: 0.0875186	best: 0.0875186 (44)	total: 1.36s	remaining: 1.67s
# 45:	learn: 0.0819002	test: 0.0859745	best: 0.0859745 (45)	total: 1.39s	remaining: 1.63s
# 46:	learn: 0.0814229	test: 0.0856812	best: 0.0856812 (46)	total: 1.42s	remaining: 1.6s
# 47:	learn: 0.0808618	test: 0.0850228	best: 0.0850228 (47)	total: 1.44s	remaining: 1.56s
# 48:	learn: 0.0800304	test: 0.0849206	best: 0.0849206 (48)	total: 1.47s	remaining: 1.53s
# 49:	learn: 0.0790782	test: 0.0845449	best: 0.0845449 (49)	total: 1.5s	remaining: 1.5s
# 50:	learn: 0.0785442	test: 0.0844466	best: 0.0844466 (50)	total: 1.53s	remaining: 1.47s
# 51:	learn: 0.0782689	test: 0.0842266	best: 0.0842266 (51)	total: 1.55s	remaining: 1.44s
# 52:	learn: 0.0775811	test: 0.0843408	best: 0.0842266 (51)	total: 1.58s	remaining: 1.4s
# 53:	learn: 0.0766882	test: 0.0846147	best: 0.0842266 (51)	total: 1.61s	remaining: 1.37s
# 54:	learn: 0.0759868	test: 0.0839860	best: 0.0839860 (54)	total: 1.64s	remaining: 1.34s
# 55:	learn: 0.0755515	test: 0.0841189	best: 0.0839860 (54)	total: 1.67s	remaining: 1.31s
# 56:	learn: 0.0749334	test: 0.0839400	best: 0.0839400 (56)	total: 1.7s	remaining: 1.28s
# 57:	learn: 0.0742693	test: 0.0829516	best: 0.0829516 (57)	total: 1.73s	remaining: 1.25s
# 58:	learn: 0.0738187	test: 0.0822838	best: 0.0822838 (58)	total: 1.76s	remaining: 1.22s
# 59:	learn: 0.0733912	test: 0.0814024	best: 0.0814024 (59)	total: 1.79s	remaining: 1.19s
# 60:	learn: 0.0730761	test: 0.0814905	best: 0.0814024 (59)	total: 1.82s	remaining: 1.16s
# 61:	learn: 0.0728153	test: 0.0813585	best: 0.0813585 (61)	total: 1.85s	remaining: 1.13s
# 62:	learn: 0.0717926	test: 0.0811245	best: 0.0811245 (62)	total: 1.88s	remaining: 1.1s
# 63:	learn: 0.0710246	test: 0.0816514	best: 0.0811245 (62)	total: 1.91s	remaining: 1.07s
# 64:	learn: 0.0698597	test: 0.0811138	best: 0.0811138 (64)	total: 1.94s	remaining: 1.04s
# 65:	learn: 0.0693267	test: 0.0807475	best: 0.0807475 (65)	total: 1.97s	remaining: 1.01s
# 66:	learn: 0.0687285	test: 0.0798877	best: 0.0798877 (66)	total: 2s	remaining: 984ms
# 67:	learn: 0.0683674	test: 0.0796379	best: 0.0796379 (67)	total: 2.03s	remaining: 954ms
# 68:	learn: 0.0678100	test: 0.0794722	best: 0.0794722 (68)	total: 2.06s	remaining: 923ms
# 69:	learn: 0.0673496	test: 0.0796833	best: 0.0794722 (68)	total: 2.09s	remaining: 895ms
# 70:	learn: 0.0669446	test: 0.0795277	best: 0.0794722 (68)	total: 2.12s	remaining: 865ms
# 71:	learn: 0.0661195	test: 0.0795447	best: 0.0794722 (68)	total: 2.15s	remaining: 836ms
# 72:	learn: 0.0655348	test: 0.0788551	best: 0.0788551 (72)	total: 2.18s	remaining: 807ms
# 73:	learn: 0.0651665	test: 0.0788042	best: 0.0788042 (73)	total: 2.21s	remaining: 776ms
# 74:	learn: 0.0648370	test: 0.0778311	best: 0.0778311 (74)	total: 2.24s	remaining: 746ms
# 75:	learn: 0.0642844	test: 0.0775201	best: 0.0775201 (75)	total: 2.27s	remaining: 716ms
# 76:	learn: 0.0640472	test: 0.0776080	best: 0.0775201 (75)	total: 2.29s	remaining: 685ms
# 77:	learn: 0.0639587	test: 0.0777022	best: 0.0775201 (75)	total: 2.32s	remaining: 655ms
# 78:	learn: 0.0632097	test: 0.0771588	best: 0.0771588 (78)	total: 2.35s	remaining: 626ms
# 79:	learn: 0.0625920	test: 0.0774260	best: 0.0771588 (78)	total: 2.38s	remaining: 596ms
# 80:	learn: 0.0621354	test: 0.0778301	best: 0.0771588 (78)	total: 2.41s	remaining: 566ms
# 81:	learn: 0.0617049	test: 0.0779011	best: 0.0771588 (78)	total: 2.44s	remaining: 536ms
# 82:	learn: 0.0614028	test: 0.0784091	best: 0.0771588 (78)	total: 2.47s	remaining: 506ms
# 83:	learn: 0.0607771	test: 0.0781068	best: 0.0771588 (78)	total: 2.5s	remaining: 477ms
# 84:	learn: 0.0603158	test: 0.0784237	best: 0.0771588 (78)	total: 2.54s	remaining: 448ms
# 85:	learn: 0.0596848	test: 0.0784318	best: 0.0771588 (78)	total: 2.57s	remaining: 418ms
# 86:	learn: 0.0590565	test: 0.0786340	best: 0.0771588 (78)	total: 2.6s	remaining: 388ms
# 87:	learn: 0.0588475	test: 0.0788208	best: 0.0771588 (78)	total: 2.62s	remaining: 358ms
# 88:	learn: 0.0584665	test: 0.0786689	best: 0.0771588 (78)	total: 2.65s	remaining: 328ms
# 89:	learn: 0.0576421	test: 0.0785307	best: 0.0771588 (78)	total: 2.68s	remaining: 298ms
# 90:	learn: 0.0571496	test: 0.0788834	best: 0.0771588 (78)	total: 2.71s	remaining: 268ms
# 91:	learn: 0.0567691	test: 0.0798751	best: 0.0771588 (78)	total: 2.74s	remaining: 238ms
# 92:	learn: 0.0563046	test: 0.0793308	best: 0.0771588 (78)	total: 2.77s	remaining: 208ms
# 93:	learn: 0.0560276	test: 0.0790256	best: 0.0771588 (78)	total: 2.8s	remaining: 179ms
# 94:	learn: 0.0556979	test: 0.0790820	best: 0.0771588 (78)	total: 2.83s	remaining: 149ms
# 95:	learn: 0.0552084	test: 0.0790424	best: 0.0771588 (78)	total: 2.85s	remaining: 119ms
# 96:	learn: 0.0548667	test: 0.0788453	best: 0.0771588 (78)	total: 2.88s	remaining: 89.1ms
# 97:	learn: 0.0543737	test: 0.0785212	best: 0.0771588 (78)	total: 2.91s	remaining: 59.4ms
# 98:	learn: 0.0538524	test: 0.0789616	best: 0.0771588 (78)	total: 2.94s	remaining: 29.7ms
# 99:	learn: 0.0530726	test: 0.0787626	best: 0.0771588 (78)	total: 2.97s	remaining: 0us
#
# bestTest = 0.07715879506
# bestIteration = 78
#
# Shrink model to first 79 iterations.

# %%
print("\nTest  Accuracy : %f"%eval_metric(Y_test.values, test_preds, "Accuracy")[0])
print("Train Accuracy : %f"%eval_metric(Y_train.values, train_preds, "Accuracy")[0])
# Out:
# Test  Accuracy : 0.981563
# Train Accuracy : 0.979928

# %%
names = ['0- нет QRS', '1- QRS']
fig, ax = plt.subplots(figsize=(8, 8))
print('Матрица несоответствий ":\n')
disp = ConfusionMatrixDisplay(confusion_matrix(Y_test.values, test_preds), display_labels = names)
disp.plot(cmap = 'Blues', ax=ax);
# Out:
# Матрица несоответствий ":

# %%
figure(figsize=(14, 2), dpi=80)
plt.plot(Y_test.values, label='general truth')
plt.plot(test_preds, label='result')
plt.xlim([100, 500])
plt.legend();

# %% [markdown]
# Посмотрим, а где же он именоо ошибается:

# %%
# False negative
fn = []
for i in range(len(Y_test.values)):
    if (Y_test.values[i] == 1) & (test_preds[i] == 0):
        fn.append(str(i))
print(', '.join(fn))
# Out:
# 166, 167, 168, 408, 462, 470, 471, 472

# %%
# False Positive
fp = []
for i in range(len(Y_test.values)):
    if (Y_test.values[i] == 0) & (test_preds[i] == 1):
        fp.append(str(i))
print(', '.join(fp))
# Out:
# 26, 83, 132, 264, 277, 280, 298, 313, 336, 425, 465, 473, 503, 612, 768, 967, 1233

# %% [markdown]
# #### На самом деле класс 1, но классификатор отнес к 0:

# %%
fig, axes = plt.subplots(3, 2, figsize=(15,8))
for i, ax in enumerate(axes.flatten()):
    ax.plot(df_test.iloc[int(fn[i]) , :200])
plt.show()

# %% [markdown]
# #### На самом деле класс 0, но классификатор отнес к 1:

# %%
fig, axes = plt.subplots(3, 3, figsize=(15,8))
for i, ax in enumerate(axes.flatten()):
    ax.plot(df_test.iloc[int(fp[i]) , :200])
plt.show()

# %% [markdown]
# Как видно некотороые такие ошибки скорее связаны с ошибками в работе пикового детектора, который и заложен в проверке качества тестового предсказания

# %% [markdown]
# __Попробуем воспользоваться обученным классификатором и применим его немного для другой задачи. Теперь будем на незнакомом тестовом сигнале находить места пиков.__

# %%
data_check = pd.read_csv('D:\Python_notebooks\project_files\ECG/233.csv')
signal_check = data_check[columns[1]].values
figure(figsize=(15, 3), dpi=80)
signal_check = signal_check[0:50000]
plt.plot(signal_check[100:5000]);

# %%
window = 200
dataset_check = []
middles = []
for i in range(0, len(signal_check)-window, 6):
    piece = signal_check[i:i+window] / np.max(np.abs(signal_check[i:i+window]))
    piece = piece - np.mean(piece)
    is_peak = 0
    middle = (i + i + window) / 2
    middles.append(middle)
    dataset_check.append(piece)

# %%
df_check = pd.DataFrame(dataset_check)
test_preds = booster.predict(df_check, prediction_type="Class")

# %%
df_check.head()
# Out:
#         0         1         2         3         4         5         6
# 0 -0.017941 -0.017941 -0.017941 -0.017941 -0.017941 -0.017941 -0.017941  \
# 1 -0.018151 -0.018151 -0.018151 -0.017327 -0.016503 -0.014032 -0.012385
# 2 -0.012500 -0.009205 -0.007558 -0.005086 -0.000968  0.006446  0.013035
# 3  0.013336  0.022397  0.033105  0.045461  0.057817  0.070997  0.087471
# 4  0.089160  0.104811  0.123756  0.139407  0.146820  0.143526  0.122109
#
#         7         8         9    ...       190       191       192       193
# 0 -0.017941 -0.017941 -0.017117  ... -0.009703 -0.010527 -0.007232 -0.007232  \
# 1 -0.009090 -0.007442 -0.004971  ... -0.010737 -0.011561 -0.012385 -0.014032
# 2  0.022096  0.032805  0.045161  ... -0.011676 -0.010029 -0.009205 -0.009205
# 3  0.103122  0.122068  0.137718  ... -0.012199 -0.013023 -0.015494 -0.015494
# 4  0.080099  0.020791 -0.054168  ... -0.014629 -0.012158 -0.011334 -0.009687
#
#         194       195       196       197       198       199
# 0 -0.006409 -0.008056 -0.010527 -0.011351 -0.012175 -0.013822
# 1 -0.014032 -0.013208 -0.011561 -0.009914 -0.009090 -0.009090
# 2 -0.010853 -0.011676 -0.012500 -0.013324 -0.015795 -0.015795
# 3 -0.014671 -0.017965 -0.016318 -0.013847 -0.013023 -0.011376
# 4 -0.010511 -0.012982 -0.012982 -0.016277 -0.014629 -0.017100
#
# [5 rows x 200 columns]

# %%
peaks = np.where(test_preds>0)[0]
middles = np.asarray(middles)
figure(figsize=(15, 3), dpi=80)
plt.plot(signal_check)
plt.scatter(middles[peaks], [list(signal_check)[x] for x in list((middles[peaks]).astype(np.int64))], color='red')
plt.xlim([0, 5000]);

# %% [markdown]
# Рассмотрим еще один тестовой сигнал (на нем не обучались):

# %%
data_check = pd.read_csv('D:\Python_notebooks\project_files\ECG/234.csv')
signal_check = data_check[columns[1]].values
figure(figsize=(15, 3), dpi=80)
signal_check = signal_check[0:50000]
plt.plot(signal_check[100:5000]);

# %%
window = 200
dataset_check = []
middles = []
for i in range(0, len(signal_check)-window, 6):
    piece = signal_check[i:i+window] / np.max(np.abs(signal_check[i:i+window]))
    piece = piece - np.mean(piece)
    is_peak = 0
    middle = (i + i + window) / 2
    middles.append(middle)
    dataset_check.append(piece)
df_check = pd.DataFrame(dataset_check)
test_preds = booster.predict(df_check, prediction_type="Class")
peaks = np.where(test_preds>0)[0]
middles = np.asarray(middles)
figure(figsize=(15, 3), dpi=80)
plt.plot(signal_check)
plt.scatter(middles[peaks], [list(signal_check)[x] for x in list((middles[peaks]).astype(np.int64))], color='red')
plt.xlim([0, 5000]);

# %% [markdown]
# Тем самым мы смогли на незнакомом сигнале без очевидного заранее известного периода седцебиения довольно точно детектировать области QRS комплекса.

# %% [markdown]
# Тем самым мы можем на любом сигнале ЭКГ с любой частотой серцебиения находить места QRS комплексов, что в случае пикового детектирования делать сложно, ведь для пикового детектирования всегда надо знать оптимальное значение размера окна, которое определяется частотой колебания сердца

# %%
# Сохраним обученную модель:
booster.save_model('boosting_model_ECG.cbm')
